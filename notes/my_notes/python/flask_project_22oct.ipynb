# %%
'''http://api.weatherapi.com/v1/current.json?key=fe233e7c62774816bde163107240801&q=kolkata'''
# Out:
# 'http://api.weatherapi.com/v1/current.json?key=fe233e7c62774816bde163107240801&q=kolkata'

# %%
'''/current.json or /current.xml
Forecast	/forecast.json or /forecast.xml
Search or Autocomplete	/search.json or /search.xml
History	/history.json or /history.xml
Marine	/marine.json or /marine.xml
Future	/future.json or /future.xml
Time Zone	/timezone.json or /timezone.xml
Sports	/sports.json or /sports.xml
Astronomy	/astronomy.json or /astronomy.xml
IP Lookup	/ip.json or /ip.xml'''
# Out:
# '/current.json or /current.xml\nForecast\t/forecast.json or /forecast.xml\nSearch or Autocomplete\t/search.json or /search.xml\nHistory\t/history.json or /history.xml\nMarine\t/marine.json or /marine.xml\nFuture\t/future.json or /future.xml\nTime Zone\t/timezone.json or /timezone.xml\nSports\t/sports.json or /sports.xml\nAstronomy\t/astronomy.json or /astronomy.xml\nIP Lookup\t/ip.json or /ip.xml'

# %%
url="http://api.weatherapi.com/v1/forecast.json"
apikey="fe233e7c62774816bde163107240801"

# %%
params={'q':"kolkata",
        'key':apikey,
        'aqi':'yes',
        'days':2}

# %%
import requests

# %%
data=requests.get(url,params=params)

# %%
data
# Out:
# <Response [200]>

# %%
data.json()
# Out:
# {'location': {'name': 'Kolkata',
#   'region': 'West Bengal',
#   'country': 'India',
#   'lat': 22.57,
#   'lon': 88.37,
#   'tz_id': 'Asia/Kolkata',
#   'localtime_epoch': 1704816595,
#   'localtime': '2024-01-09 21:39'},
#  'current': {'last_updated_epoch': 1704816000,
#   'last_updated': '2024-01-09 21:30',
#   'temp_c': 18.0,
#   'temp_f': 64.4,
#   'is_day': 0,
#   'condition': {'text': 'Mist',
#    'icon': '//cdn.weatherapi.com/weather/64x64/night/143.png',
#    'code': 1030},
#   'wind_mph': 2.2,
#   'wind_kph': 3.6,
#   'wind_degree': 10,
#   'wind_dir': 'N',
#   'pressure_mb': 1016.0,
#   'pressure_in': 30.0,
#   'precip_mm': 0.0,
#   'precip_in': 0.0,
#   'humidity': 83,
#   'cloud': 0,
#   'feelslike_c': 18.0,
#   'feelslike_f': 64.4,
#   'vis_km': 2.4,
#   'vis_miles': 1.0,
#   'uv': 1.0,
#   'gust_mph': 8.5,
#   'gust_kph': 13.6,
#   'air_quality': {'co': 2697.0,
#    'no2': 79.5,
#    'o3': 36.5,
#    'so2': 75.3,
#    'pm2_5': 244.9,
#    'pm10': 372.2,
#    'us-epa-index': 5,
#    'gb-defra-index': 10}},
#  'forecast': {'forecastday': [{'date': '2024-01-09',
#     'date_epoch': 1704758400,
#     'day': {'maxtemp_c': 27.7,
#      'maxtemp_f': 81.8,
#      'mintemp_c': 15.5,
#      'mintemp_f': 59.8,
#      'avgtemp_c': 21.2,
#      'avgtemp_f': 70.2,
#      'maxwind_mph': 14.1,
#      'maxwind_kph': 22.7,
#      'totalprecip_mm': 0.0,
#      'totalprecip_in': 0.0,
#      'totalsnow_cm': 0.0,
#      'avgvis_km': 10.0,
#      'avgvis_miles': 6.0,
#      'avghumidity': 42,
#      'daily_will_it_rain': 0,
#      'daily_chance_of_rain': 0,
#      'daily_will_it_snow': 0,
#      'daily_chance_of_snow': 0,
#      'condition': {'text': 'Sunny',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#       'code': 1000},
#      'uv': 5.0,
#      'air_quality': {'co': 2307.8624999999997,
#       'no2': 55.287499999999994,
#       'o3': 53.933333333333316,
#       'so2': 49.50416666666667,
#       'pm2_5': 245.96666666666667,
#       'pm10': 343.5833333333333,
#       'us-epa-index': 5,
#       'gb-defra-index': 10}},
#     'astro': {'sunrise': '06:18 AM',
#      'sunset': '05:09 PM',
#      'moonrise': '04:03 AM',
#      'moonset': '02:49 PM',
#      'moon_phase': 'Waning Crescent',
#      'moon_illumination': 8,
#      'is_moon_up': 1,
#      'is_sun_up': 0},
#     'hour': [{'time_epoch': 1704738600,
#       'time': '2024-01-09 00:00',
#       'temp_c': 18.7,
#       'temp_f': 65.7,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 5.6,
#       'wind_kph': 9.0,
#       'wind_degree': 355,
#       'wind_dir': 'N',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.02,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 53,
#       'cloud': 0,
#       'feelslike_c': 18.7,
#       'feelslike_f': 65.7,
#       'windchill_c': 18.7,
#       'windchill_f': 65.7,
#       'heatindex_c': 18.7,
#       'heatindex_f': 65.7,
#       'dewpoint_c': 9.0,
#       'dewpoint_f': 48.3,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 11.3,
#       'gust_kph': 18.3,
#       'uv': 1.0,
#       'air_quality': {'co': 4486.1,
#        'no2': 101.5,
#        'o3': 0.0,
#        'so2': 53.4,
#        'pm2_5': 477.4,
#        'pm10': 632.5,
#        'us-epa-index': 6,
#        'gb-defra-index': 10}},
#      {'time_epoch': 1704742200,
#       'time': '2024-01-09 01:00',
#       'temp_c': 18.3,
#       'temp_f': 64.9,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 6.5,
#       'wind_kph': 10.4,
#       'wind_degree': 349,
#       'wind_dir': 'N',
#       'pressure_mb': 1016.0,
#       'pressure_in': 30.02,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 54,
#       'cloud': 2,
#       'feelslike_c': 18.3,
#       'feelslike_f': 64.9,
#       'windchill_c': 18.3,
#       'windchill_f': 64.9,
#       'heatindex_c': 18.3,
#       'heatindex_f': 64.9,
#       'dewpoint_c': 8.9,
#       'dewpoint_f': 48.1,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 13.1,
#       'gust_kph': 21.0,
#       'uv': 1.0,
#       'air_quality': {'co': 4165.7,
#        'no2': 87.1,
#        'o3': 0.0,
#        'so2': 34.8,
#        'pm2_5': 457.3,
#        'pm10': 608.7,
#        'us-epa-index': 6,
#        'gb-defra-index': 10}},
#      {'time_epoch': 1704745800,
#       'time': '2024-01-09 02:00',
#       'temp_c': 17.3,
#       'temp_f': 63.1,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 7.4,
#       'wind_kph': 11.9,
#       'wind_degree': 351,
#       'wind_dir': 'N',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.02,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 60,
#       'cloud': 3,
#       'feelslike_c': 17.3,
#       'feelslike_f': 63.1,
#       'windchill_c': 17.3,
#       'windchill_f': 63.1,
#       'heatindex_c': 17.3,
#       'heatindex_f': 63.1,
#       'dewpoint_c': 9.5,
#       'dewpoint_f': 49.1,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 14.3,
#       'gust_kph': 23.0,
#       'uv': 1.0,
#       'air_quality': {'co': 3845.2,
#        'no2': 72.7,
#        'o3': 0.0,
#        'so2': 22.2,
#        'pm2_5': 434.2,
#        'pm10': 589.4,
#        'us-epa-index': 6,
#        'gb-defra-index': 10}},
#      {'time_epoch': 1704749400,
#       'time': '2024-01-09 03:00',
#       'temp_c': 16.7,
#       'temp_f': 62.1,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 7.8,
#       'wind_kph': 12.6,
#       'wind_degree': 356,
#       'wind_dir': 'N',
#       'pressure_mb': 1016.0,
#       'pressure_in': 30.01,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 61,
#       'cloud': 3,
#       'feelslike_c': 16.8,
#       'feelslike_f': 62.2,
#       'windchill_c': 16.8,
#       'windchill_f': 62.2,
#       'heatindex_c': 16.8,
#       'heatindex_f': 62.2,
#       'dewpoint_c': 9.2,
#       'dewpoint_f': 48.5,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 15.2,
#       'gust_kph': 24.5,
#       'uv': 1.0,
#       'air_quality': {'co': 3337.9,
#        'no2': 57.6,
#        'o3': 0.0,
#        'so2': 14.3,
#        'pm2_5': 387.0,
#        'pm10': 536.6,
#        'us-epa-index': 6,
#        'gb-defra-index': 10}},
#      {'time_epoch': 1704753000,
#       'time': '2024-01-09 04:00',
#       'temp_c': 16.2,
#       'temp_f': 61.2,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 8.1,
#       'wind_kph': 13.0,
#       'wind_degree': 0,
#       'wind_dir': 'N',
#       'pressure_mb': 1016.0,
#       'pressure_in': 30.02,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 62,
#       'cloud': 4,
#       'feelslike_c': 16.2,
#       'feelslike_f': 61.2,
#       'windchill_c': 16.2,
#       'windchill_f': 61.2,
#       'heatindex_c': 16.2,
#       'heatindex_f': 61.2,
#       'dewpoint_c': 8.9,
#       'dewpoint_f': 48.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 15.8,
#       'gust_kph': 25.5,
#       'uv': 1.0,
#       'air_quality': {'co': 2937.3,
#        'no2': 47.3,
#        'o3': 0.0,
#        'so2': 11.7,
#        'pm2_5': 349.3,
#        'pm10': 474.5,
#        'us-epa-index': 6,
#        'gb-defra-index': 10}},
#      {'time_epoch': 1704756600,
#       'time': '2024-01-09 05:00',
#       'temp_c': 15.8,
#       'temp_f': 60.5,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 7.6,
#       'wind_kph': 12.2,
#       'wind_degree': 3,
#       'wind_dir': 'N',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.03,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 62,
#       'cloud': 4,
#       'feelslike_c': 15.8,
#       'feelslike_f': 60.5,
#       'windchill_c': 15.8,
#       'windchill_f': 60.5,
#       'heatindex_c': 15.8,
#       'heatindex_f': 60.5,
#       'dewpoint_c': 8.6,
#       'dewpoint_f': 47.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 15.1,
#       'gust_kph': 24.3,
#       'uv': 1.0,
#       'air_quality': {'co': 2723.7,
#        'no2': 42.8,
#        'o3': 0.0,
#        'so2': 12.4,
#        'pm2_5': 329.4,
#        'pm10': 422.0,
#        'us-epa-index': 6,
#        'gb-defra-index': 10}},
#      {'time_epoch': 1704760200,
#       'time': '2024-01-09 06:00',
#       'temp_c': 15.5,
#       'temp_f': 59.8,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 7.6,
#       'wind_kph': 12.2,
#       'wind_degree': 5,
#       'wind_dir': 'N',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.05,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 64,
#       'cloud': 4,
#       'feelslike_c': 15.5,
#       'feelslike_f': 59.8,
#       'windchill_c': 15.5,
#       'windchill_f': 59.8,
#       'heatindex_c': 15.5,
#       'heatindex_f': 59.8,
#       'dewpoint_c': 8.7,
#       'dewpoint_f': 47.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 15.0,
#       'gust_kph': 24.1,
#       'uv': 5.0,
#       'air_quality': {'co': 2483.4,
#        'no2': 48.7,
#        'o3': 0.6,
#        'so2': 21.0,
#        'pm2_5': 310.4,
#        'pm10': 371.4,
#        'us-epa-index': 6,
#        'gb-defra-index': 10}},
#      {'time_epoch': 1704763800,
#       'time': '2024-01-09 07:00',
#       'temp_c': 17.2,
#       'temp_f': 62.9,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 8.1,
#       'wind_kph': 13.0,
#       'wind_degree': 7,
#       'wind_dir': 'N',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.06,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 59,
#       'cloud': 4,
#       'feelslike_c': 17.2,
#       'feelslike_f': 62.9,
#       'windchill_c': 17.2,
#       'windchill_f': 62.9,
#       'heatindex_c': 17.2,
#       'heatindex_f': 62.9,
#       'dewpoint_c': 9.2,
#       'dewpoint_f': 48.5,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 12.3,
#       'gust_kph': 19.8,
#       'uv': 5.0,
#       'air_quality': {'co': 2510.1,
#        'no2': 50.0,
#        'o3': 2.3,
#        'so2': 27.9,
#        'pm2_5': 301.5,
#        'pm10': 365.2,
#        'us-epa-index': 6,
#        'gb-defra-index': 10}},
#      {'time_epoch': 1704767400,
#       'time': '2024-01-09 08:00',
#       'temp_c': 19.7,
#       'temp_f': 67.4,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 8.5,
#       'wind_kph': 13.7,
#       'wind_degree': 11,
#       'wind_dir': 'NNE',
#       'pressure_mb': 1019.0,
#       'pressure_in': 30.09,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 52,
#       'cloud': 3,
#       'feelslike_c': 19.7,
#       'feelslike_f': 67.4,
#       'windchill_c': 19.7,
#       'windchill_f': 67.4,
#       'heatindex_c': 19.7,
#       'heatindex_f': 67.4,
#       'dewpoint_c': 9.6,
#       'dewpoint_f': 49.2,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 10.2,
#       'gust_kph': 16.4,
#       'uv': 5.0,
#       'air_quality': {'co': 2483.4,
#        'no2': 46.6,
#        'o3': 13.4,
#        'so2': 34.8,
#        'pm2_5': 288.1,
#        'pm10': 361.2,
#        'us-epa-index': 6,
#        'gb-defra-index': 10}},
#      {'time_epoch': 1704771000,
#       'time': '2024-01-09 09:00',
#       'temp_c': 22.0,
#       'temp_f': 71.6,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 8.5,
#       'wind_kph': 13.7,
#       'wind_degree': 11,
#       'wind_dir': 'NNE',
#       'pressure_mb': 1019.0,
#       'pressure_in': 30.09,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 43,
#       'cloud': 4,
#       'feelslike_c': 24.2,
#       'feelslike_f': 75.5,
#       'windchill_c': 22.0,
#       'windchill_f': 71.7,
#       'heatindex_c': 24.2,
#       'heatindex_f': 75.5,
#       'dewpoint_c': 9.0,
#       'dewpoint_f': 48.2,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 9.8,
#       'gust_kph': 15.7,
#       'uv': 6.0,
#       'air_quality': {'co': 2136.2,
#        'no2': 47.3,
#        'o3': 44.0,
#        'so2': 53.9,
#        'pm2_5': 264.4,
#        'pm10': 331.1,
#        'us-epa-index': 6,
#        'gb-defra-index': 10}},
#      {'time_epoch': 1704774600,
#       'time': '2024-01-09 10:00',
#       'temp_c': 24.1,
#       'temp_f': 75.3,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 9.4,
#       'wind_kph': 15.1,
#       'wind_degree': 4,
#       'wind_dir': 'N',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.06,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 35,
#       'cloud': 5,
#       'feelslike_c': 24.5,
#       'feelslike_f': 76.2,
#       'windchill_c': 24.1,
#       'windchill_f': 75.3,
#       'heatindex_c': 24.5,
#       'heatindex_f': 76.2,
#       'dewpoint_c': 7.7,
#       'dewpoint_f': 45.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 10.8,
#       'gust_kph': 17.4,
#       'uv': 6.0,
#       'air_quality': {'co': 2109.5,
#        'no2': 48.0,
#        'o3': 76.5,
#        'so2': 59.6,
#        'pm2_5': 276.5,
#        'pm10': 348.8,
#        'us-epa-index': 6,
#        'gb-defra-index': 10}},
#      {'time_epoch': 1704778200,
#       'time': '2024-01-09 11:00',
#       'temp_c': 25.7,
#       'temp_f': 78.3,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 10.1,
#       'wind_kph': 16.2,
#       'wind_degree': 358,
#       'wind_dir': 'N',
#       'pressure_mb': 1016.0,
#       'pressure_in': 30.02,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 29,
#       'cloud': 4,
#       'feelslike_c': 25.1,
#       'feelslike_f': 77.2,
#       'windchill_c': 25.7,
#       'windchill_f': 78.3,
#       'heatindex_c': 25.1,
#       'heatindex_f': 77.2,
#       'dewpoint_c': 6.6,
#       'dewpoint_f': 43.8,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 11.6,
#       'gust_kph': 18.6,
#       'uv': 7.0,
#       'air_quality': {'co': 1762.4,
#        'no2': 31.9,
#        'o3': 144.5,
#        'so2': 50.1,
#        'pm2_5': 259.9,
#        'pm10': 324.7,
#        'us-epa-index': 6,
#        'gb-defra-index': 10}},
#      {'time_epoch': 1704781800,
#       'time': '2024-01-09 12:00',
#       'temp_c': 26.8,
#       'temp_f': 80.3,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 10.7,
#       'wind_kph': 17.3,
#       'wind_degree': 353,
#       'wind_dir': 'N',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.97,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 27,
#       'cloud': 4,
#       'feelslike_c': 25.7,
#       'feelslike_f': 78.3,
#       'windchill_c': 26.8,
#       'windchill_f': 80.3,
#       'heatindex_c': 25.7,
#       'heatindex_f': 78.3,
#       'dewpoint_c': 6.1,
#       'dewpoint_f': 42.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 12.3,
#       'gust_kph': 19.9,
#       'uv': 7.0,
#       'air_quality': {'co': 854.5,
#        'no2': 10.0,
#        'o3': 173.1,
#        'so2': 26.9,
#        'pm2_5': 131.2,
#        'pm10': 156.7,
#        'us-epa-index': 4,
#        'gb-defra-index': 10}},
#      {'time_epoch': 1704785400,
#       'time': '2024-01-09 13:00',
#       'temp_c': 27.5,
#       'temp_f': 81.6,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 11.9,
#       'wind_kph': 19.1,
#       'wind_degree': 346,
#       'wind_dir': 'NNW',
#       'pressure_mb': 1014.0,
#       'pressure_in': 29.95,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 25,
#       'cloud': 3,
#       'feelslike_c': 26.1,
#       'feelslike_f': 79.0,
#       'windchill_c': 27.6,
#       'windchill_f': 81.6,
#       'heatindex_c': 26.1,
#       'heatindex_f': 79.0,
#       'dewpoint_c': 5.8,
#       'dewpoint_f': 42.4,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 13.6,
#       'gust_kph': 22.0,
#       'uv': 7.0,
#       'air_quality': {'co': 627.5,
#        'no2': 6.0,
#        'o3': 167.4,
#        'so2': 16.5,
#        'pm2_5': 86.4,
#        'pm10': 103.2,
#        'us-epa-index': 4,
#        'gb-defra-index': 10}},
#      {'time_epoch': 1704789000,
#       'time': '2024-01-09 14:00',
#       'temp_c': 27.7,
#       'temp_f': 81.8,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 13.4,
#       'wind_kph': 21.6,
#       'wind_degree': 341,
#       'wind_dir': 'NNW',
#       'pressure_mb': 1014.0,
#       'pressure_in': 29.93,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 24,
#       'cloud': 3,
#       'feelslike_c': 26.2,
#       'feelslike_f': 79.1,
#       'windchill_c': 27.7,
#       'windchill_f': 81.8,
#       'heatindex_c': 26.2,
#       'heatindex_f': 79.1,
#       'dewpoint_c': 5.6,
#       'dewpoint_f': 42.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 15.4,
#       'gust_kph': 24.8,
#       'uv': 7.0,
#       'air_quality': {'co': 587.5,
#        'no2': 6.3,
#        'o3': 164.5,
#        'so2': 14.9,
#        'pm2_5': 81.1,
#        'pm10': 96.5,
#        'us-epa-index': 4,
#        'gb-defra-index': 10}},
#      {'time_epoch': 1704792600,
#       'time': '2024-01-09 15:00',
#       'temp_c': 27.2,
#       'temp_f': 81.0,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 14.1,
#       'wind_kph': 22.7,
#       'wind_degree': 338,
#       'wind_dir': 'NNW',
#       'pressure_mb': 1014.0,
#       'pressure_in': 29.93,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 25,
#       'cloud': 3,
#       'feelslike_c': 25.8,
#       'feelslike_f': 78.5,
#       'windchill_c': 27.2,
#       'windchill_f': 81.0,
#       'heatindex_c': 25.8,
#       'heatindex_f': 78.5,
#       'dewpoint_c': 5.3,
#       'dewpoint_f': 41.5,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 17.4,
#       'gust_kph': 27.9,
#       'uv': 7.0,
#       'air_quality': {'co': 807.8,
#        'no2': 16.1,
#        'o3': 138.8,
#        'so2': 19.1,
#        'pm2_5': 95.1,
#        'pm10': 123.6,
#        'us-epa-index': 4,
#        'gb-defra-index': 10}},
#      {'time_epoch': 1704796200,
#       'time': '2024-01-09 16:00',
#       'temp_c': 26.0,
#       'temp_f': 78.7,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 11.2,
#       'wind_kph': 18.0,
#       'wind_degree': 341,
#       'wind_dir': 'NNW',
#       'pressure_mb': 1014.0,
#       'pressure_in': 29.93,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 27,
#       'cloud': 2,
#       'feelslike_c': 25.1,
#       'feelslike_f': 77.2,
#       'windchill_c': 26.0,
#       'windchill_f': 78.7,
#       'heatindex_c': 25.1,
#       'heatindex_f': 77.2,
#       'dewpoint_c': 5.6,
#       'dewpoint_f': 42.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 16.7,
#       'gust_kph': 26.9,
#       'uv': 7.0,
#       'air_quality': {'co': 1094.8,
#        'no2': 30.2,
#        'o3': 107.3,
#        'so2': 23.8,
#        'pm2_5': 116.1,
#        'pm10': 162.8,
#        'us-epa-index': 4,
#        'gb-defra-index': 10}},
#      {'time_epoch': 1704799800,
#       'time': '2024-01-09 17:00',
#       'temp_c': 23.4,
#       'temp_f': 74.1,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 6.0,
#       'wind_kph': 9.7,
#       'wind_degree': 351,
#       'wind_dir': 'N',
#       'pressure_mb': 1014.0,
#       'pressure_in': 29.95,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 31,
#       'cloud': 0,
#       'feelslike_c': 23.9,
#       'feelslike_f': 75.1,
#       'windchill_c': 23.4,
#       'windchill_f': 74.1,
#       'heatindex_c': 23.9,
#       'heatindex_f': 75.1,
#       'dewpoint_c': 5.4,
#       'dewpoint_f': 41.7,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 12.3,
#       'gust_kph': 19.7,
#       'uv': 1.0,
#       'air_quality': {'co': 1321.8,
#        'no2': 42.8,
#        'o3': 80.8,
#        'so2': 28.9,
#        'pm2_5': 132.4,
#        'pm10': 192.6,
#        'us-epa-index': 4,
#        'gb-defra-index': 10}},
#      {'time_epoch': 1704803400,
#       'time': '2024-01-09 18:00',
#       'temp_c': 22.4,
#       'temp_f': 72.4,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 4.7,
#       'wind_kph': 7.6,
#       'wind_degree': 17,
#       'wind_dir': 'NNE',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.96,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 33,
#       'cloud': 0,
#       'feelslike_c': 23.7,
#       'feelslike_f': 74.6,
#       'windchill_c': 22.5,
#       'windchill_f': 72.4,
#       'heatindex_c': 23.7,
#       'heatindex_f': 74.6,
#       'dewpoint_c': 5.4,
#       'dewpoint_f': 41.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 9.9,
#       'gust_kph': 15.9,
#       'uv': 1.0,
#       'air_quality': {'co': 1628.9,
#        'no2': 54.8,
#        'o3': 65.1,
#        'so2': 39.6,
#        'pm2_5': 153.0,
#        'pm10': 229.1,
#        'us-epa-index': 5,
#        'gb-defra-index': 10}},
#      {'time_epoch': 1704807000,
#       'time': '2024-01-09 19:00',
#       'temp_c': 21.6,
#       'temp_f': 70.9,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 5.1,
#       'wind_kph': 8.3,
#       'wind_degree': 35,
#       'wind_dir': 'NE',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.97,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 35,
#       'cloud': 0,
#       'feelslike_c': 21.6,
#       'feelslike_f': 70.8,
#       'windchill_c': 21.6,
#       'windchill_f': 70.8,
#       'heatindex_c': 23.6,
#       'heatindex_f': 74.4,
#       'dewpoint_c': 5.3,
#       'dewpoint_f': 41.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 10.8,
#       'gust_kph': 17.4,
#       'uv': 1.0,
#       'air_quality': {'co': 2002.7,
#        'no2': 63.1,
#        'o3': 52.2,
#        'so2': 50.6,
#        'pm2_5': 179.8,
#        'pm10': 277.3,
#        'us-epa-index': 5,
#        'gb-defra-index': 10}},
#      {'time_epoch': 1704810600,
#       'time': '2024-01-09 20:00',
#       'temp_c': 20.8,
#       'temp_f': 69.4,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 4.9,
#       'wind_kph': 7.9,
#       'wind_degree': 40,
#       'wind_dir': 'NE',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.97,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 36,
#       'cloud': 0,
#       'feelslike_c': 20.8,
#       'feelslike_f': 69.4,
#       'windchill_c': 20.8,
#       'windchill_f': 69.4,
#       'heatindex_c': 20.8,
#       'heatindex_f': 69.4,
#       'dewpoint_c': 5.2,
#       'dewpoint_f': 41.4,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 10.3,
#       'gust_kph': 16.6,
#       'uv': 1.0,
#       'air_quality': {'co': 2323.2,
#        'no2': 69.2,
#        'o3': 44.0,
#        'so2': 61.0,
#        'pm2_5': 209.9,
#        'pm10': 326.0,
#        'us-epa-index': 5,
#        'gb-defra-index': 10}},
#      {'time_epoch': 1704814200,
#       'time': '2024-01-09 21:00',
#       'temp_c': 18.0,
#       'temp_f': 64.4,
#       'is_day': 0,
#       'condition': {'text': 'Mist',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/143.png',
#        'code': 1030},
#       'wind_mph': 2.2,
#       'wind_kph': 3.6,
#       'wind_degree': 10,
#       'wind_dir': 'N',
#       'pressure_mb': 1016.0,
#       'pressure_in': 30.0,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 83,
#       'cloud': 0,
#       'feelslike_c': 20.2,
#       'feelslike_f': 68.3,
#       'windchill_c': 20.2,
#       'windchill_f': 68.3,
#       'heatindex_c': 20.2,
#       'heatindex_f': 68.3,
#       'dewpoint_c': 5.1,
#       'dewpoint_f': 41.2,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 2.4,
#       'vis_miles': 1.0,
#       'gust_mph': 8.5,
#       'gust_kph': 13.6,
#       'uv': 1.0,
#       'air_quality': {'co': 2697.0,
#        'no2': 79.5,
#        'o3': 36.5,
#        'so2': 75.3,
#        'pm2_5': 244.9,
#        'pm10': 372.2,
#        'us-epa-index': 5,
#        'gb-defra-index': 10}},
#      {'time_epoch': 1704817800,
#       'time': '2024-01-09 22:00',
#       'temp_c': 19.7,
#       'temp_f': 67.5,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 4.0,
#       'wind_kph': 6.5,
#       'wind_degree': 23,
#       'wind_dir': 'NNE',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.97,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 38,
#       'cloud': 0,
#       'feelslike_c': 19.7,
#       'feelslike_f': 67.5,
#       'windchill_c': 19.7,
#       'windchill_f': 67.5,
#       'heatindex_c': 19.7,
#       'heatindex_f': 67.5,
#       'dewpoint_c': 5.0,
#       'dewpoint_f': 41.1,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 8.5,
#       'gust_kph': 13.6,
#       'uv': 1.0,
#       'air_quality': {'co': 3204.4,
#        'no2': 93.2,
#        'o3': 17.5,
#        'so2': 89.7,
#        'pm2_5': 287.1,
#        'pm10': 423.7,
#        'us-epa-index': 6,
#        'gb-defra-index': 10}},
#      {'time_epoch': 1704821400,
#       'time': '2024-01-09 23:00',
#       'temp_c': 19.2,
#       'temp_f': 66.5,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 3.8,
#       'wind_kph': 6.1,
#       'wind_degree': 10,
#       'wind_dir': 'N',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.96,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 39,
#       'cloud': 2,
#       'feelslike_c': 19.2,
#       'feelslike_f': 66.5,
#       'windchill_c': 19.2,
#       'windchill_f': 66.5,
#       'heatindex_c': 19.2,
#       'heatindex_f': 66.5,
#       'dewpoint_c': 4.9,
#       'dewpoint_f': 40.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 8.0,
#       'gust_kph': 12.9,
#       'uv': 1.0,
#       'air_quality': {'co': 3631.6,
#        'no2': 100.1,
#        'o3': 1.6,
#        'so2': 95.4,
#        'pm2_5': 321.9,
#        'pm10': 458.6,
#        'us-epa-index': 6,
#        'gb-defra-index': 10}}]},
#    {'date': '2024-01-10',
#     'date_epoch': 1704844800,
#     'day': {'maxtemp_c': 28.6,
#      'maxtemp_f': 83.5,
#      'mintemp_c': 16.9,
#      'mintemp_f': 62.5,
#      'avgtemp_c': 22.5,
#      'avgtemp_f': 72.5,
#      'maxwind_mph': 10.1,
#      'maxwind_kph': 16.2,
#      'totalprecip_mm': 0.0,
#      'totalprecip_in': 0.0,
#      'totalsnow_cm': 0.0,
#      'avgvis_km': 10.0,
#      'avgvis_miles': 6.0,
#      'avghumidity': 37,
#      'daily_will_it_rain': 0,
#      'daily_chance_of_rain': 0,
#      'daily_will_it_snow': 0,
#      'daily_chance_of_snow': 0,
#      'condition': {'text': 'Sunny',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#       'code': 1000},
#      'uv': 5.0,
#      'air_quality': {'co': 2456.108333333333,
#       'no2': 60.33333333333334,
#       'o3': 48.42499999999998,
#       'so2': 57.362500000000004,
#       'pm2_5': 333.67499999999995,
#       'pm10': 428.24166666666673,
#       'us-epa-index': 6,
#       'gb-defra-index': 10}},
#     'astro': {'sunrise': '06:18 AM',
#      'sunset': '05:09 PM',
#      'moonrise': '05:07 AM',
#      'moonset': '03:50 PM',
#      'moon_phase': 'Waning Crescent',
#      'moon_illumination': 3,
#      'is_moon_up': 1,
#      'is_sun_up': 0},
#     'hour': [{'time_epoch': 1704825000,
#       'time': '2024-01-10 00:00',
#       'temp_c': 18.7,
#       'temp_f': 65.7,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 4.3,
#       'wind_kph': 6.8,
#       'wind_degree': 7,
#       'wind_dir': 'N',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.96,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 40,
#       'cloud': 3,
#       'feelslike_c': 18.7,
#       'feelslike_f': 65.7,
#       'windchill_c': 18.7,
#       'windchill_f': 65.7,
#       'heatindex_c': 18.7,
#       'heatindex_f': 65.7,
#       'dewpoint_c': 4.8,
#       'dewpoint_f': 40.7,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 8.9,
#       'gust_kph': 14.4,
#       'uv': 1.0,
#       'air_quality': {'co': 3685.0,
#        'no2': 97.3,
#        'o3': 0.1,
#        'so2': 93.5,
#        'pm2_5': 330.1,
#        'pm10': 457.6,
#        'us-epa-index': 6,
#        'gb-defra-index': 10}},
#      {'time_epoch': 1704828600,
#       'time': '2024-01-10 01:00',
#       'temp_c': 18.2,
#       'temp_f': 64.8,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 4.9,
#       'wind_kph': 7.9,
#       'wind_degree': 4,
#       'wind_dir': 'N',
#       'pressure_mb': 1014.0,
#       'pressure_in': 29.96,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 41,
#       'cloud': 3,
#       'feelslike_c': 18.2,
#       'feelslike_f': 64.8,
#       'windchill_c': 18.2,
#       'windchill_f': 64.8,
#       'heatindex_c': 18.2,
#       'heatindex_f': 64.8,
#       'dewpoint_c': 4.6,
#       'dewpoint_f': 40.4,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 10.3,
#       'gust_kph': 16.6,
#       'uv': 1.0,
#       'air_quality': {'co': 3524.8,
#        'no2': 97.3,
#        'o3': 0.1,
#        'so2': 92.5,
#        'pm2_5': 331.1,
#        'pm10': 458.5,
#        'us-epa-index': 6,
#        'gb-defra-index': 10}},
#      {'time_epoch': 1704832200,
#       'time': '2024-01-10 02:00',
#       'temp_c': 17.8,
#       'temp_f': 64.0,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 4.0,
#       'wind_kph': 6.5,
#       'wind_degree': 10,
#       'wind_dir': 'N',
#       'pressure_mb': 1014.0,
#       'pressure_in': 29.95,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 41,
#       'cloud': 4,
#       'feelslike_c': 17.8,
#       'feelslike_f': 64.0,
#       'windchill_c': 17.8,
#       'windchill_f': 64.0,
#       'heatindex_c': 17.8,
#       'heatindex_f': 64.0,
#       'dewpoint_c': 4.5,
#       'dewpoint_f': 40.1,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 8.5,
#       'gust_kph': 13.6,
#       'uv': 1.0,
#       'air_quality': {'co': 3418.0,
#        'no2': 97.3,
#        'o3': 0.2,
#        'so2': 85.8,
#        'pm2_5': 334.4,
#        'pm10': 469.2,
#        'us-epa-index': 6,
#        'gb-defra-index': 10}},
#      {'time_epoch': 1704835800,
#       'time': '2024-01-10 03:00',
#       'temp_c': 17.4,
#       'temp_f': 63.4,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 3.6,
#       'wind_kph': 5.8,
#       'wind_degree': 14,
#       'wind_dir': 'NNE',
#       'pressure_mb': 1014.0,
#       'pressure_in': 29.94,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 42,
#       'cloud': 4,
#       'feelslike_c': 17.4,
#       'feelslike_f': 63.4,
#       'windchill_c': 17.4,
#       'windchill_f': 63.4,
#       'heatindex_c': 17.4,
#       'heatindex_f': 63.4,
#       'dewpoint_c': 4.4,
#       'dewpoint_f': 39.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 7.5,
#       'gust_kph': 12.1,
#       'uv': 1.0,
#       'air_quality': {'co': 3044.1,
#        'no2': 85.0,
#        'o3': 0.4,
#        'so2': 67.7,
#        'pm2_5': 319.4,
#        'pm10': 457.9,
#        'us-epa-index': 6,
#        'gb-defra-index': 10}},
#      {'time_epoch': 1704839400,
#       'time': '2024-01-10 04:00',
#       'temp_c': 17.1,
#       'temp_f': 62.9,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 2.5,
#       'wind_kph': 4.0,
#       'wind_degree': 8,
#       'wind_dir': 'N',
#       'pressure_mb': 1014.0,
#       'pressure_in': 29.95,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 43,
#       'cloud': 5,
#       'feelslike_c': 17.1,
#       'feelslike_f': 62.9,
#       'windchill_c': 17.1,
#       'windchill_f': 62.9,
#       'heatindex_c': 17.1,
#       'heatindex_f': 62.9,
#       'dewpoint_c': 4.4,
#       'dewpoint_f': 39.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 5.2,
#       'gust_kph': 8.3,
#       'uv': 1.0,
#       'air_quality': {'co': 2697.0,
#        'no2': 67.9,
#        'o3': 0.4,
#        'so2': 48.6,
#        'pm2_5': 309.4,
#        'pm10': 444.1,
#        'us-epa-index': 6,
#        'gb-defra-index': 10}},
#      {'time_epoch': 1704843000,
#       'time': '2024-01-10 05:00',
#       'temp_c': 17.1,
#       'temp_f': 62.7,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 2.7,
#       'wind_kph': 4.3,
#       'wind_degree': 346,
#       'wind_dir': 'NNW',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.98,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 43,
#       'cloud': 5,
#       'feelslike_c': 17.1,
#       'feelslike_f': 62.7,
#       'windchill_c': 17.1,
#       'windchill_f': 62.7,
#       'heatindex_c': 17.1,
#       'heatindex_f': 62.7,
#       'dewpoint_c': 4.4,
#       'dewpoint_f': 39.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 5.6,
#       'gust_kph': 9.1,
#       'uv': 1.0,
#       'air_quality': {'co': 2563.5,
#        'no2': 54.8,
#        'o3': 0.2,
#        'so2': 35.3,
#        'pm2_5': 313.4,
#        'pm10': 434.9,
#        'us-epa-index': 6,
#        'gb-defra-index': 10}},
#      {'time_epoch': 1704846600,
#       'time': '2024-01-10 06:00',
#       'temp_c': 16.9,
#       'temp_f': 62.5,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 2.5,
#       'wind_kph': 4.0,
#       'wind_degree': 353,
#       'wind_dir': 'N',
#       'pressure_mb': 1016.0,
#       'pressure_in': 29.99,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 44,
#       'cloud': 5,
#       'feelslike_c': 16.9,
#       'feelslike_f': 62.5,
#       'windchill_c': 16.9,
#       'windchill_f': 62.5,
#       'heatindex_c': 16.9,
#       'heatindex_f': 62.5,
#       'dewpoint_c': 4.7,
#       'dewpoint_f': 40.4,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 5.2,
#       'gust_kph': 8.3,
#       'uv': 5.0,
#       'air_quality': {'co': 2643.6,
#        'no2': 47.3,
#        'o3': 0.0,
#        'so2': 29.3,
#        'pm2_5': 324.9,
#        'pm10': 444.7,
#        'us-epa-index': 6,
#        'gb-defra-index': 10}},
#      {'time_epoch': 1704850200,
#       'time': '2024-01-10 07:00',
#       'temp_c': 19.0,
#       'temp_f': 66.2,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 2.0,
#       'wind_kph': 3.2,
#       'wind_degree': 349,
#       'wind_dir': 'N',
#       'pressure_mb': 1016.0,
#       'pressure_in': 30.01,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 40,
#       'cloud': 6,
#       'feelslike_c': 19.0,
#       'feelslike_f': 66.1,
#       'windchill_c': 19.0,
#       'windchill_f': 66.1,
#       'heatindex_c': 19.0,
#       'heatindex_f': 66.1,
#       'dewpoint_c': 5.1,
#       'dewpoint_f': 41.2,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 3.2,
#       'gust_kph': 5.1,
#       'uv': 5.0,
#       'air_quality': {'co': 2964.0,
#        'no2': 42.8,
#        'o3': 0.8,
#        'so2': 30.5,
#        'pm2_5': 345.3,
#        'pm10': 478.1,
#        'us-epa-index': 6,
#        'gb-defra-index': 10}},
#      {'time_epoch': 1704853800,
#       'time': '2024-01-10 08:00',
#       'temp_c': 21.1,
#       'temp_f': 70.0,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 3.1,
#       'wind_kph': 5.0,
#       'wind_degree': 335,
#       'wind_dir': 'NNW',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.03,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 36,
#       'cloud': 6,
#       'feelslike_c': 21.1,
#       'feelslike_f': 70.0,
#       'windchill_c': 21.1,
#       'windchill_f': 70.0,
#       'heatindex_c': 23.6,
#       'heatindex_f': 74.4,
#       'dewpoint_c': 5.5,
#       'dewpoint_f': 41.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 4.0,
#       'gust_kph': 6.5,
#       'uv': 6.0,
#       'air_quality': {'co': 3150.9,
#        'no2': 40.1,
#        'o3': 5.6,
#        'so2': 32.0,
#        'pm2_5': 355.7,
#        'pm10': 497.8,
#        'us-epa-index': 6,
#        'gb-defra-index': 10}},
#      {'time_epoch': 1704857400,
#       'time': '2024-01-10 09:00',
#       'temp_c': 23.3,
#       'temp_f': 74.0,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 5.4,
#       'wind_kph': 8.6,
#       'wind_degree': 335,
#       'wind_dir': 'NNW',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.04,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 33,
#       'cloud': 5,
#       'feelslike_c': 24.1,
#       'feelslike_f': 75.3,
#       'windchill_c': 23.3,
#       'windchill_f': 74.0,
#       'heatindex_c': 24.1,
#       'heatindex_f': 75.3,
#       'dewpoint_c': 6.3,
#       'dewpoint_f': 43.3,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 6.2,
#       'gust_kph': 10.0,
#       'uv': 6.0,
#       'air_quality': {'co': 2697.0,
#        'no2': 45.9,
#        'o3': 26.8,
#        'so2': 37.7,
#        'pm2_5': 322.2,
#        'pm10': 433.7,
#        'us-epa-index': 6,
#        'gb-defra-index': 10}},
#      {'time_epoch': 1704861000,
#       'time': '2024-01-10 10:00',
#       'temp_c': 25.1,
#       'temp_f': 77.2,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 6.3,
#       'wind_kph': 10.1,
#       'wind_degree': 326,
#       'wind_dir': 'NNW',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.02,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 31,
#       'cloud': 4,
#       'feelslike_c': 24.8,
#       'feelslike_f': 76.7,
#       'windchill_c': 25.1,
#       'windchill_f': 77.1,
#       'heatindex_c': 24.8,
#       'heatindex_f': 76.7,
#       'dewpoint_c': 6.7,
#       'dewpoint_f': 44.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 7.2,
#       'gust_kph': 11.6,
#       'uv': 7.0,
#       'air_quality': {'co': 2456.7,
#        'no2': 48.0,
#        'o3': 66.5,
#        'so2': 43.4,
#        'pm2_5': 318.5,
#        'pm10': 422.5,
#        'us-epa-index': 6,
#        'gb-defra-index': 10}},
#      {'time_epoch': 1704864600,
#       'time': '2024-01-10 11:00',
#       'temp_c': 26.6,
#       'temp_f': 79.9,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 7.8,
#       'wind_kph': 12.6,
#       'wind_degree': 329,
#       'wind_dir': 'NNW',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.98,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 29,
#       'cloud': 5,
#       'feelslike_c': 25.7,
#       'feelslike_f': 78.3,
#       'windchill_c': 26.6,
#       'windchill_f': 79.9,
#       'heatindex_c': 25.7,
#       'heatindex_f': 78.3,
#       'dewpoint_c': 7.0,
#       'dewpoint_f': 44.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 9.0,
#       'gust_kph': 14.5,
#       'uv': 7.0,
#       'air_quality': {'co': 2216.3,
#        'no2': 43.9,
#        'o3': 124.5,
#        'so2': 48.6,
#        'pm2_5': 327.2,
#        'pm10': 423.0,
#        'us-epa-index': 6,
#        'gb-defra-index': 10}},
#      {'time_epoch': 1704868200,
#       'time': '2024-01-10 12:00',
#       'temp_c': 27.6,
#       'temp_f': 81.7,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 7.8,
#       'wind_kph': 12.6,
#       'wind_degree': 329,
#       'wind_dir': 'NNW',
#       'pressure_mb': 1013.0,
#       'pressure_in': 29.92,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 28,
#       'cloud': 4,
#       'feelslike_c': 26.5,
#       'feelslike_f': 79.6,
#       'windchill_c': 27.6,
#       'windchill_f': 81.7,
#       'heatindex_c': 26.5,
#       'heatindex_f': 79.6,
#       'dewpoint_c': 7.4,
#       'dewpoint_f': 45.4,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 9.0,
#       'gust_kph': 14.5,
#       'uv': 7.0,
#       'air_quality': {'co': 1134.9,
#        'no2': 23.3,
#        'o3': 165.9,
#        'so2': 75.3,
#        'pm2_5': 227.7,
#        'pm10': 269.5,
#        'us-epa-index': 5,
#        'gb-defra-index': 10}},
#      {'time_epoch': 1704871800,
#       'time': '2024-01-10 13:00',
#       'temp_c': 28.4,
#       'temp_f': 83.2,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 8.7,
#       'wind_kph': 14.0,
#       'wind_degree': 331,
#       'wind_dir': 'NNW',
#       'pressure_mb': 1012.0,
#       'pressure_in': 29.89,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 27,
#       'cloud': 4,
#       'feelslike_c': 27.1,
#       'feelslike_f': 80.8,
#       'windchill_c': 28.4,
#       'windchill_f': 83.2,
#       'heatindex_c': 27.1,
#       'heatindex_f': 80.8,
#       'dewpoint_c': 7.8,
#       'dewpoint_f': 46.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 10.0,
#       'gust_kph': 16.2,
#       'uv': 7.0,
#       'air_quality': {'co': 894.6,
#        'no2': 19.7,
#        'o3': 170.2,
#        'so2': 89.7,
#        'pm2_5': 200.0,
#        'pm10': 231.1,
#        'us-epa-index': 5,
#        'gb-defra-index': 10}},
#      {'time_epoch': 1704875400,
#       'time': '2024-01-10 14:00',
#       'temp_c': 28.6,
#       'temp_f': 83.5,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 10.1,
#       'wind_kph': 16.2,
#       'wind_degree': 331,
#       'wind_dir': 'NNW',
#       'pressure_mb': 1012.0,
#       'pressure_in': 29.88,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 27,
#       'cloud': 4,
#       'feelslike_c': 27.3,
#       'feelslike_f': 81.1,
#       'windchill_c': 28.6,
#       'windchill_f': 83.5,
#       'heatindex_c': 27.3,
#       'heatindex_f': 81.1,
#       'dewpoint_c': 8.0,
#       'dewpoint_f': 46.4,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 11.6,
#       'gust_kph': 18.6,
#       'uv': 7.0,
#       'air_quality': {'co': 854.5,
#        'no2': 19.0,
#        'o3': 178.8,
#        'so2': 88.7,
#        'pm2_5': 191.9,
#        'pm10': 220.2,
#        'us-epa-index': 5,
#        'gb-defra-index': 10}},
#      {'time_epoch': 1704879000,
#       'time': '2024-01-10 15:00',
#       'temp_c': 28.3,
#       'temp_f': 82.9,
#       'is_day': 1,
# ...
#       'feelslike_f': 67.8,
#       'windchill_c': 19.9,
#       'windchill_f': 67.8,
#       'heatindex_c': 21.2,
#       'heatindex_f': 70.2,
#       'dewpoint_c': 3.3,
#       'dewpoint_f': 37.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 11.9,
#       'gust_kph': 19.1,
#       'uv': 5.0,
#       'air_quality': {}},
#      {'time_epoch': 1705890600,
#       'time': '2024-01-22 08:00',
#       'temp_c': 21.2,
#       'temp_f': 70.2,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 9.6,
#       'wind_kph': 15.5,
#       'wind_degree': 0,
#       'wind_dir': 'N',
#       'pressure_mb': 1016.0,
#       'pressure_in': 29.99,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 31,
#       'cloud': 4,
#       'feelslike_c': 21.2,
#       'feelslike_f': 70.2,
#       'windchill_c': 21.2,
#       'windchill_f': 70.2,
#       'heatindex_c': 23.1,
#       'heatindex_f': 73.7,
#       'dewpoint_c': 3.5,
#       'dewpoint_f': 38.3,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 11.5,
#       'gust_kph': 18.5,
#       'uv': 6.0,
#       'air_quality': {}},
#      {'time_epoch': 1705894200,
#       'time': '2024-01-22 09:00',
#       'temp_c': 23.0,
#       'temp_f': 73.4,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 9.6,
#       'wind_kph': 15.5,
#       'wind_degree': 115,
#       'wind_dir': 'ESE',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.98,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 28,
#       'cloud': 3,
#       'feelslike_c': 23.7,
#       'feelslike_f': 74.7,
#       'windchill_c': 23.0,
#       'windchill_f': 73.4,
#       'heatindex_c': 23.7,
#       'heatindex_f': 74.7,
#       'dewpoint_c': 3.1,
#       'dewpoint_f': 37.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 11.4,
#       'gust_kph': 18.4,
#       'uv': 6.0,
#       'air_quality': {}},
#      {'time_epoch': 1705897800,
#       'time': '2024-01-22 10:00',
#       'temp_c': 24.7,
#       'temp_f': 76.5,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 9.8,
#       'wind_kph': 15.8,
#       'wind_degree': 230,
#       'wind_dir': 'SW',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.97,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 24,
#       'cloud': 3,
#       'feelslike_c': 24.3,
#       'feelslike_f': 75.7,
#       'windchill_c': 24.7,
#       'windchill_f': 76.5,
#       'heatindex_c': 24.3,
#       'heatindex_f': 75.7,
#       'dewpoint_c': 2.8,
#       'dewpoint_f': 37.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 11.4,
#       'gust_kph': 18.4,
#       'uv': 6.0,
#       'air_quality': {}},
#      {'time_epoch': 1705901400,
#       'time': '2024-01-22 11:00',
#       'temp_c': 26.5,
#       'temp_f': 79.7,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 9.8,
#       'wind_kph': 15.8,
#       'wind_degree': 345,
#       'wind_dir': 'NNW',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.96,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 21,
#       'cloud': 2,
#       'feelslike_c': 24.9,
#       'feelslike_f': 76.9,
#       'windchill_c': 26.5,
#       'windchill_f': 79.7,
#       'heatindex_c': 24.9,
#       'heatindex_f': 76.9,
#       'dewpoint_c': 2.4,
#       'dewpoint_f': 36.4,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 11.3,
#       'gust_kph': 18.2,
#       'uv': 7.0,
#       'air_quality': {}},
#      {'time_epoch': 1705905000,
#       'time': '2024-01-22 12:00',
#       'temp_c': 26.8,
#       'temp_f': 80.2,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 10.1,
#       'wind_kph': 16.2,
#       'wind_degree': 338,
#       'wind_dir': 'NNW',
#       'pressure_mb': 1014.0,
#       'pressure_in': 29.93,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 20,
#       'cloud': 2,
#       'feelslike_c': 25.2,
#       'feelslike_f': 77.4,
#       'windchill_c': 26.8,
#       'windchill_f': 80.2,
#       'heatindex_c': 25.2,
#       'heatindex_f': 77.4,
#       'dewpoint_c': 2.1,
#       'dewpoint_f': 35.8,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 11.6,
#       'gust_kph': 18.7,
#       'uv': 7.0,
#       'air_quality': {}},
#      {'time_epoch': 1705908600,
#       'time': '2024-01-22 13:00',
#       'temp_c': 27.2,
#       'temp_f': 81.0,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 10.3,
#       'wind_kph': 16.6,
#       'wind_degree': 332,
#       'wind_dir': 'NNW',
#       'pressure_mb': 1013.0,
#       'pressure_in': 29.9,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 19,
#       'cloud': 2,
#       'feelslike_c': 25.4,
#       'feelslike_f': 77.7,
#       'windchill_c': 27.2,
#       'windchill_f': 81.0,
#       'heatindex_c': 25.4,
#       'heatindex_f': 77.7,
#       'dewpoint_c': 1.8,
#       'dewpoint_f': 35.2,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 11.9,
#       'gust_kph': 19.1,
#       'uv': 7.0,
#       'air_quality': {}},
#      {'time_epoch': 1705912200,
#       'time': '2024-01-22 14:00',
#       'temp_c': 27.5,
#       'temp_f': 81.6,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 10.5,
#       'wind_kph': 16.9,
#       'wind_degree': 326,
#       'wind_dir': 'NNW',
#       'pressure_mb': 1011.0,
#       'pressure_in': 29.87,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 19,
#       'cloud': 2,
#       'feelslike_c': 25.6,
#       'feelslike_f': 78.2,
#       'windchill_c': 27.5,
#       'windchill_f': 81.6,
#       'heatindex_c': 25.6,
#       'heatindex_f': 78.2,
#       'dewpoint_c': 1.5,
#       'dewpoint_f': 34.8,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 12.1,
#       'gust_kph': 19.5,
#       'uv': 7.0,
#       'air_quality': {}},
#      {'time_epoch': 1705915800,
#       'time': '2024-01-22 15:00',
#       'temp_c': 26.1,
#       'temp_f': 79.0,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 9.6,
#       'wind_kph': 15.5,
#       'wind_degree': 333,
#       'wind_dir': 'NNW',
#       'pressure_mb': 1012.0,
#       'pressure_in': 29.88,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 20,
#       'cloud': 1,
#       'feelslike_c': 24.8,
#       'feelslike_f': 76.6,
#       'windchill_c': 26.1,
#       'windchill_f': 79.0,
#       'heatindex_c': 24.8,
#       'heatindex_f': 76.6,
#       'dewpoint_c': 1.3,
#       'dewpoint_f': 34.3,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 13.4,
#       'gust_kph': 21.6,
#       'uv': 7.0,
#       'air_quality': {}},
#      {'time_epoch': 1705919400,
#       'time': '2024-01-22 16:00',
#       'temp_c': 24.7,
#       'temp_f': 76.5,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 8.9,
#       'wind_kph': 14.4,
#       'wind_degree': 340,
#       'wind_dir': 'NNW',
#       'pressure_mb': 1012.0,
#       'pressure_in': 29.89,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 21,
#       'cloud': 1,
#       'feelslike_c': 23.9,
#       'feelslike_f': 75.0,
#       'windchill_c': 24.7,
#       'windchill_f': 76.5,
#       'heatindex_c': 23.9,
#       'heatindex_f': 75.0,
#       'dewpoint_c': 1.0,
#       'dewpoint_f': 33.8,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 14.5,
#       'gust_kph': 23.4,
#       'uv': 6.0,
#       'air_quality': {}},
#      {'time_epoch': 1705923000,
#       'time': '2024-01-22 17:00',
#       'temp_c': 23.3,
#       'temp_f': 74.0,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 8.1,
#       'wind_kph': 13.0,
#       'wind_degree': 346,
#       'wind_dir': 'NNW',
#       'pressure_mb': 1013.0,
#       'pressure_in': 29.9,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 22,
#       'cloud': 0,
#       'feelslike_c': 23.1,
#       'feelslike_f': 73.5,
#       'windchill_c': 23.4,
#       'windchill_f': 74.0,
#       'heatindex_c': 23.1,
#       'heatindex_f': 73.5,
#       'dewpoint_c': 0.8,
#       'dewpoint_f': 33.4,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 15.9,
#       'gust_kph': 25.6,
#       'uv': 1.0,
#       'air_quality': {}},
#      {'time_epoch': 1705926600,
#       'time': '2024-01-22 18:00',
#       'temp_c': 22.4,
#       'temp_f': 72.3,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 7.6,
#       'wind_kph': 12.2,
#       'wind_degree': 238,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1013.0,
#       'pressure_in': 29.92,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 25,
#       'cloud': 0,
#       'feelslike_c': 22.3,
#       'feelslike_f': 72.1,
#       'windchill_c': 22.4,
#       'windchill_f': 72.3,
#       'heatindex_c': 22.3,
#       'heatindex_f': 72.1,
#       'dewpoint_c': 1.3,
#       'dewpoint_f': 34.3,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 15.2,
#       'gust_kph': 24.5,
#       'uv': 1.0,
#       'air_quality': {}},
#      {'time_epoch': 1705930200,
#       'time': '2024-01-22 19:00',
#       'temp_c': 21.5,
#       'temp_f': 70.7,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 7.2,
#       'wind_kph': 11.5,
#       'wind_degree': 130,
#       'wind_dir': 'SE',
#       'pressure_mb': 1014.0,
#       'pressure_in': 29.95,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 27,
#       'cloud': 0,
#       'feelslike_c': 21.5,
#       'feelslike_f': 70.7,
#       'windchill_c': 21.5,
#       'windchill_f': 70.7,
#       'heatindex_c': 21.4,
#       'heatindex_f': 70.5,
#       'dewpoint_c': 1.9,
#       'dewpoint_f': 35.4,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 14.8,
#       'gust_kph': 23.8,
#       'uv': 1.0,
#       'air_quality': {}},
#      {'time_epoch': 1705933800,
#       'time': '2024-01-22 20:00',
#       'temp_c': 20.6,
#       'temp_f': 69.1,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 6.7,
#       'wind_kph': 10.8,
#       'wind_degree': 21,
#       'wind_dir': 'NNE',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.97,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 30,
#       'cloud': 0,
#       'feelslike_c': 20.6,
#       'feelslike_f': 69.1,
#       'windchill_c': 20.6,
#       'windchill_f': 69.1,
#       'heatindex_c': 20.6,
#       'heatindex_f': 69.1,
#       'dewpoint_c': 2.5,
#       'dewpoint_f': 36.4,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 14.1,
#       'gust_kph': 22.7,
#       'uv': 1.0,
#       'air_quality': {}},
#      {'time_epoch': 1705937400,
#       'time': '2024-01-22 21:00',
#       'temp_c': 20.2,
#       'temp_f': 68.4,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 6.9,
#       'wind_kph': 11.2,
#       'wind_degree': 131,
#       'wind_dir': 'SE',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.96,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 31,
#       'cloud': 0,
#       'feelslike_c': 20.2,
#       'feelslike_f': 68.4,
#       'windchill_c': 20.2,
#       'windchill_f': 68.4,
#       'heatindex_c': 20.2,
#       'heatindex_f': 68.4,
#       'dewpoint_c': 2.5,
#       'dewpoint_f': 36.5,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 14.3,
#       'gust_kph': 23.0,
#       'uv': 1.0,
#       'air_quality': {}},
#      {'time_epoch': 1705941000,
#       'time': '2024-01-22 22:00',
#       'temp_c': 19.8,
#       'temp_f': 67.6,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 6.9,
#       'wind_kph': 11.2,
#       'wind_degree': 241,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.96,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 32,
#       'cloud': 0,
#       'feelslike_c': 19.8,
#       'feelslike_f': 67.6,
#       'windchill_c': 19.8,
#       'windchill_f': 67.6,
#       'heatindex_c': 19.8,
#       'heatindex_f': 67.6,
#       'dewpoint_c': 2.5,
#       'dewpoint_f': 36.5,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 14.8,
#       'gust_kph': 23.8,
#       'uv': 1.0,
#       'air_quality': {}},
#      {'time_epoch': 1705944600,
#       'time': '2024-01-22 23:00',
#       'temp_c': 19.5,
#       'temp_f': 67.0,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 7.2,
#       'wind_kph': 11.5,
#       'wind_degree': 351,
#       'wind_dir': 'N',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.96,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 32,
#       'cloud': 0,
#       'feelslike_c': 19.5,
#       'feelslike_f': 67.0,
#       'windchill_c': 19.5,
#       'windchill_f': 67.0,
#       'heatindex_c': 19.5,
#       'heatindex_f': 67.0,
#       'dewpoint_c': 2.5,
#       'dewpoint_f': 36.5,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 15.0,
#       'gust_kph': 24.2,
#       'uv': 1.0,
#       'air_quality': {}}]}]}}
